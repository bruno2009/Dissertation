# %% [markdown]
# <a href="https://colab.research.google.com/github/bruno2009/Dissertation/blob/main/C%C3%B3pia_de_Deep_learning_Medical_Image.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install python3-wget
# token = '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'
# !git clone https://bruno2009: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@github.com/bruno2009/Image-Medica.git
# Out:
# Cloning into 'Image-Medica'...
# remote: Enumerating objects: 125, done.
# remote: Counting objects: 100% (125/125), done.
# remote: Compressing objects: 100% (104/104), done.
# remote: Total 125 (delta 27), reused 112 (delta 20), pack-reused 0
# Receiving objects: 100% (125/125), 5.71 MiB | 32.46 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2

# %%
im = cv2.imread('/content/Image-Medica/Dataset/GT/gt_c10.jpg')

im_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

plt.imshow(im_rgb)
plt.show()

# %%
im = cv2.imread('/content/Image-Medica/Dataset/GT/gt_c11.jpg')

im_rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)

plt.imshow(im_rgb)
plt.show()
